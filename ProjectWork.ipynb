# %%
# Import Dependencies
import pandas as pd
import numpy as np
from config import api_key
import requests
from pprint import pprint

# %%
# Define API base url and targetted years of movies data
url1 = "https://api.themoviedb.org/3/discover/movie?"
start_date = "2018-01-01"
end_date = "2018-03-04"

# %%
# Call the API url , Check for response and print the response whether the data is available or not
# store the repsonse as JSON data
response = requests.get(f"{url1}api_key={api_key}&primary_release_date.gte={start_date}&primary_release_date.lte={end_date}")
movies_data = response.json()
pprint(movies_data)
movies_data_list = [movie for movie in movies_data["results"]]
pprint(movies_data_list)
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#               'backdrop_path': '/9ywA15OAiwjSTvg3cBs9B7kOCBF.jpg',
#               'genre_ids': [18, 10749],
#               'id': 337167,
#               'original_language': 'en',
#               'original_title': 'Fifty Shades Freed',
#               'overview': 'Believing they have left behind shadowy figures '
#                           'from their past, newlyweds Christian and Ana fully '
#                           'embrace an inextricable connection and shared life '
#                           'of luxury. But just as she steps into her role as '
#                           'Mrs. Grey and he relaxes into an unfamiliar '
#                           'stability, new threats could jeopardize their happy '
#                           'ending before it even begins.',
#               'popularity': 457.27461,
#               'poster_path': '/3kcEGnYBHDeqmdYf8ZRbKdfmlUy.jpg',
#               'release_date': '2018-02-07',
#               'title': 'Fifty Shades Freed',
#               'video': False,
#               'vote_average': 6.1,
#               'vote_count': 1196},
#              {'adult': False,
#               'backdrop_path': '/b6ZJZHUdMEFECvGiDpJjlfUWela.jpg',
#               'genre_ids': [28, 12, 14, 878],
#               'id': 284054,
#               'original_language': 'en',
#               'original_title': 'Black Panther',
#               'overview': "King T'Challa returns home from America to the "
#                           'reclusive, technologically advanced African nation '
#                           "of Wakanda to serve as his country's new leader. "
#                           "However, T'Challa soon finds that he is challenged "
#                           'for the throne by factions within his own country '
#                           'as well as without.  Using powers reserved to '
#                           "Wakandan kings, T'Challa assumes the Black Panther "
#                           'mantel to join with girlfriend Nakia, the '
#                           'queen-mother, his princess-kid sister,  members of '
#                           'the Dora Milaje (the Wakandan "special forces"), '
#                           'and an American secret agent, to prevent Wakanda '
#                           'from being dragged into a world war.',
#               'popularity': 204.155126,
#               'poster_path': '/uxzzxijgPIY7slzFvMotPv8wjKA.jpg',
#               'release_date': '2018-02-13',
#               'title': 'Black Panther',
#               'video': False,
#               'vote_average': 7.3,
#               'vote_count': 3819},
#              {'adult': False,
#               'backdrop_path': '/5zfVNTrkhMu673zma6qhFzG01ig.jpg',
#               'genre_ids': [9648, 878, 18],
#               'id': 300668,
#               'original_language': 'en',
#               'original_title': 'Annihilation',
#               'overview': 'A biologist signs up for a dangerous, secret '
#                           'expedition into a mysterious zone where the laws of '
#                           "nature don't apply.",
#               'popularity': 91.363378,
#               'poster_path': '/d3qcpfNwbAMCNqWDHzPQsUYiUgS.jpg',
#               'release_date': '2018-02-22',
#               'title': 'Annihilation',
#               'video': False,
#               'vote_average': 6.4,
#               'vote_count': 1248},
#              {'adult': False,
#               'backdrop_path': '/4QrbczSQGZQA7BG9xMhccQI7LHm.jpg',
#               'genre_ids': [18, 10749],
#               'id': 499772,
#               'original_language': 'tl',
#               'original_title': 'Meet Me In St. Gallen',
#               'overview': 'The story of Jesse and Celeste who meets at an '
#                           'unexpected time in their lives. They then realize '
#                           'their names are the same as the characters in the '
#                           'popular break-up romantic comedy, Celeste and Jesse '
#                           'Forever.',
#               'popularity': 76.285636,
#               'poster_path': '/uGntNjUx6YAzbVy7RDgxWnWsdet.jpg',
#               'release_date': '2018-02-07',
#               'title': 'Meet Me In St. Gallen',
#               'video': False,
#               'vote_average': 5.4,
#               'vote_count': 15},
#              {'adult': False,
#               'backdrop_path': '/clmYuR1t4TtKcakIOvYIPrjyxDc.jpg',
#               'genre_ids': [28, 80, 18],
#               'id': 399035,
#               'original_language': 'en',
#               'original_title': 'The Commuter',
#               'overview': 'A businessman on his daily commute home gets '
#                           'unwittingly caught up in a criminal conspiracy that '
#                           'threatens not only his life but the lives of those '
#                           'around him.',
#               'popularity': 65.501665,
#               'poster_path': '/rDeGK6FIUfVcXmuBdEORPAGPMNg.jpg',
#               'release_date': '2018-01-11',
#               'title': 'The Commuter',
#               'video': False,
#               'vote_average': 5.8,
#               'vote_count': 677},
#              {'adult': False,
#               'backdrop_path': '/PwI3EfasE9fVuXsmMu9ffJh0Re.jpg',
#               'genre_ids': [9648, 27, 53],
#               'id': 406563,
#               'original_language': 'en',
#               'original_title': 'Insidious: The Last Key',
#               'overview': 'Parapsychologist Elise Rainier and her team travel '
#                           "to Five Keys, N.M., to investigate a man's claim of "
#                           'a haunting. Terror soon strikes when Rainier '
#                           'realizes that the house he lives in was her '
#                           "family's old home.",
#               'popularity': 40.687605,
#               'poster_path': '/nb9fc9INMg8kQ8L7sE7XTNsZnUX.jpg',
#               'release_date': '2018-01-03',
#               'title': 'Insidious: The Last Key',
#               'video': False,
#               'vote_average': 6.1,
#               'vote_count': 505},
#              {'adult': False,
#               'backdrop_path': '/bvbyidkMaBls1LTaIWYY6UmYTaL.jpg',
#               'genre_ids': [28, 9648, 878, 53, 12, 14],
#               'id': 336843,
#               'original_language': 'en',
#               'original_title': 'Maze Runner: The Death Cure',
#               'overview': 'Thomas leads his group of escaped Gladers on their '
#                           'final and most dangerous mission yet. To save their '
#                           'friends, they must break into the legendary Last '
#                           'City, a WCKD-controlled labyrinth that may turn out '
#                           'to be the deadliest maze of all. Anyone who makes '
#                           'it out alive will get answers to the questions the '
#                           'Gladers have been asking since they first arrived '
#                           'in the maze.',
#               'popularity': 36.994424,
#               'poster_path': '/7GgZ6DGezkh3szFdvskH5XD4V0t.jpg',
#               'release_date': '2018-01-17',
#               'title': 'Maze Runner: The Death Cure',
#               'video': False,
#               'vote_average': 7.2,
#               'vote_count': 1108},
#              {'adult': False,
#               'backdrop_path': '/txKjPn6yuqvmdc7YGTnh62EM5Cd.jpg',
#               'genre_ids': [53, 28, 80],
#               'id': 442064,
#               'original_language': 'en',
#               'original_title': 'Proud Mary',
#               'overview': 'A hit woman kills a drug boss only to learn that '
#                           'she has left a boy orphaned. A year later, she '
#                           'saves the boy from a dangerous life on the street '
#                           'but finds herself unable to give the boy or herself '
#                           'a fresh start.',
#               'popularity': 36.143522,
#               'poster_path': '/5luceoVMU2FzWuyty7mZFcSY5ZW.jpg',
#               'release_date': '2018-01-12',
#               'title': 'Proud Mary',
#               'video': False,
#               'vote_average': 5.3,
#               'vote_count': 115},
#              {'adult': False,
#               'backdrop_path': '/iG3wzWkLcnxnwzZHYT6iyd1UqJP.jpg',
#               'genre_ids': [28],
#               'id': 401478,
#               'original_language': 'en',
#               'original_title': 'Death Race 4: Beyond Anarchy',
#               'overview': 'Danny Trejo returns as the ruthless bookie, '
#                           'Goldberg, in the wildest, bloodiest, Death Race '
#                           'ever. After a failed attack on inmate and legendary '
#                           'driver, Frankenstein, Black Ops specialist Connor '
#                           'Gibson (McGowan) infiltrates a super-maximum '
#                           'federal prison with one goal - enter the immoral '
#                           'and illegal Death Race and take Frankenstein down. '
#                           'Connor enlists the help of Baltimore Bob (Glover) '
#                           'and Lists (Koehler), and unexpectedly falls in love '
#                           'with bartending beauty, Jane (Marzano). Connor will '
#                           'have to fight for more than his life in this brutal '
#                           'world of no guards, no rules, no track, and no '
#                           'fear.',
#               'popularity': 34.590488,
#               'poster_path': '/h4CrVSJO8G2xRFgkxjPX8LCLzCk.jpg',
#               'release_date': '2018-01-30',
#               'title': 'Death Race 4: Beyond Anarchy',
#               'video': False,
#               'vote_average': 5.1,
#               'vote_count': 13},
#              {'adult': False,
#               'backdrop_path': '/xCF6Vkq1L5tTGENb07vzlQyXwKv.jpg',
#               'genre_ids': [28, 12, 14],
#               'id': 437543,
#               'original_language': 'zh',
#               'original_title': '西游记·女儿国',
#               'overview': 'The third installment of the blockbuster fantasy '
#                           'series sees the return of the Monkey King (Aaron '
#                           'Kwok) in his most action-packed adventure yet! '
#                           'While continuing their epic journey to the West, '
#                           'the Monkey King and his companions are taken '
#                           'captive by the Queen of an all-female land, who '
#                           'believes them to be part of an ancient prophecy '
#                           'heralding the fall of her kingdom. With a lot of '
#                           'sorcery and a little bit of charm, the travelers '
#                           'devise a plan to escape. But when their trickery '
#                           'angers the mighty River God, they realize they '
#                           'might just bring about the foretold destruction - '
#                           'unless they can find a way to quell her wrath.',
#               'popularity': 34.140986,
#               'poster_path': '/zMYnxPIkUVaRIuTpS77B8hLGkBB.jpg',
#               'release_date': '2018-02-16',
#               'title': 'The Monkey King 3: Kingdom of Women',
#               'video': False,
#               'vote_average': 5.3,
#               'vote_count': 8},
#              {'adult': False,
#               'backdrop_path': '/sGzuQYSTwJvLBc2PnuSVLHhuFeh.jpg',
#               'genre_ids': [9648, 53],
#               'id': 401981,
#               'original_language': 'en',
#               'original_title': 'Red Sparrow',
#               'overview': 'Prima ballerina Dominika Egorova faces a bleak and '
#                           'uncertain future after she suffers an injury that '
#                           'ends her career. She soon turns to Sparrow School, '
#                           'a secret intelligence service that trains '
#                           'exceptional young people to use their minds and '
#                           'bodies as weapons. Egorova emerges as the most '
#                           'dangerous Sparrow after completing the sadistic '
#                           'training process. As she comes to terms with her '
#                           'new abilities, Dominika meets a CIA agent who tries '
#                           'to convince her that he is the only person she can '
#                           'trust.',
#               'popularity': 33.281817,
#               'poster_path': '/fyufzd2S1lLxMxkTHTnmr6VJfe5.jpg',
#               'release_date': '2018-03-01',
#               'title': 'Red Sparrow',
#               'video': False,
#               'vote_average': 6.3,
#               'vote_count': 547},
#              {'adult': False,
#               'backdrop_path': '/lffgWEBiLf9DbDdb86WsGsEcWTg.jpg',
#               'genre_ids': [53, 18, 14],
#               'id': 419831,
#               'original_language': 'en',
#               'original_title': 'I Kill Giants',
#               'overview': 'Barbara Thorson struggles through life by escaping '
#                           'into a fantasy life of magic and monsters.',
#               'popularity': 23.829161,
#               'poster_path': '/cvit6HDbXHE6W5kGPd47jd0wthQ.jpg',
#               'release_date': '2018-01-21',
#               'title': 'I Kill Giants',
#               'video': False,
#               'vote_average': 6,
#               'vote_count': 63},
#              {'adult': False,
#               'backdrop_path': '/g1ovo0YhL9FcZmgoW4Fx6F4x1e6.jpg',
#               'genre_ids': [28, 80, 18, 53],
#               'id': 395990,
#               'original_language': 'en',
#               'original_title': 'Death Wish',
#               'overview': 'A mild-mannered father is transformed into a '
#                           'killing machine after his family is torn apart by a '
#                           'violent act.',
#               'popularity': 23.329822,
#               'poster_path': '/wamM5AyPAeNPNPfjWRI9WD8dweQ.jpg',
#               'release_date': '2018-03-02',
#               'title': 'Death Wish',
#               'video': False,
#               'vote_average': 4.6,
#               'vote_count': 167},
#              {'adult': False,
#               'backdrop_path': '/p8YMxheGzrtTJgz74EucMJyWqIy.jpg',
#               'genre_ids': [16, 12, 10751],
#               'id': 381719,
#               'original_language': 'en',
#               'original_title': 'Peter Rabbit',
#               'overview': "Feature adaptation of Beatrix Potter's classic tale "
#                           'of a rebellious rabbit trying to sneak into a '
#                           "farmer's vegetable garden.",
#               'popularity': 21.939166,
#               'poster_path': '/2yjSvEDuM3rLDng40erLsWkQRfn.jpg',
#               'release_date': '2018-02-07',
#               'title': 'Peter Rabbit',
#               'video': False,
#               'vote_average': 6.3,
#               'vote_count': 77},
#              {'adult': False,
#               'backdrop_path': '/jknYekTVH1n7doNVj5wiCMKhx7u.jpg',
#               'genre_ids': [9648, 35, 80, 53],
#               'id': 445571,
#               'original_language': 'en',
#               'original_title': 'Game Night',
#               'overview': "Max and Annie's weekly game night gets kicked up a "
#                           "notch when Max's brother Brooks arranges a murder "
#                           'mystery party -- complete with fake thugs and '
#                           "federal agents. So when Brooks gets kidnapped, it's "
#                           'all supposed to be part of the game. As the '
#                           'competitors set out to solve the case, they start '
#                           'to learn that neither the game nor Brooks are what '
#                           'they seem to be. The friends soon find themselves '
#                           'in over their heads as each twist leads to another '
#                           'unexpected turn over the course of one chaotic '
#                           'night.',
#               'popularity': 20.374195,
#               'poster_path': '/1wS89vns6cseCn4UHSqj97xKEKW.jpg',
#               'release_date': '2018-02-22',
#               'title': 'Game Night',
#               'video': False,
#               'vote_average': 7.3,
#               'vote_count': 194},
#              {'adult': False,
#               'backdrop_path': '/teunpFRDU3dBiWhGneegrjQ7uSq.jpg',
#               'genre_ids': [9648, 878, 53],
#               'id': 401371,
#               'original_language': 'en',
#               'original_title': 'Mute',
#               'overview': 'A mute man with a violent past is forced to take on '
#                           'the teeming underworld of a near-future Berlin as '
#                           'he searches for his missing girlfriend.',
#               'popularity': 20.328504,
#               'poster_path': '/ihGg1xndLl3MW34Km332pNkyLH7.jpg',
#               'release_date': '2018-02-23',
#               'title': 'Mute',
#               'video': False,
#               'vote_average': 5.6,
#               'vote_count': 236},
#              {'adult': False,
#               'backdrop_path': '/x5EUEv1N9g4BCX9GQXKvv3nqMVo.jpg',
#               'genre_ids': [10752, 18, 36],
#               'id': 429351,
#               'original_language': 'en',
#               'original_title': '12 Strong',
#               'overview': 'A team of CIA agents and special forces head into '
#                           'Afghanistan in the aftermath of the September 11th '
#                           'attacks in an attempt to dismantle the Taliban.',
#               'popularity': 19.691142,
#               'poster_path': '/j18021qCeRi3yUBtqd2UFj1c0RQ.jpg',
#               'release_date': '2018-01-18',
#               'title': '12 Strong',
#               'video': False,
#               'vote_average': 4.9,
#               'vote_count': 245},
#              {'adult': False,
#               'backdrop_path': '/uIWnlqVAQWkVXyW1mjsrlvoCItt.jpg',
#               'genre_ids': [18, 28],
#               'id': 459910,
#               'original_language': 'en',
#               'original_title': 'Braven',
#               'overview': 'A logger defends his family from a group of '
#                           'dangerous drug runners.',
#               'popularity': 18.75806,
#               'poster_path': '/253Bw5I3Zj3e2thCThjO7byEUCL.jpg',
#               'release_date': '2018-02-01',
#               'title': 'Braven',
#               'video': False,
#               'vote_average': 6.1,
#               'vote_count': 84},
#              {'adult': False,
#               'backdrop_path': '/lX4jScWnurasu6Kxuqo9819mjM2.jpg',
#               'genre_ids': [9648, 53, 27, 878],
#               'id': 384521,
#               'original_language': 'en',
#               'original_title': 'The Cloverfield Paradox',
#               'overview': 'Orbiting above a planet on the brink of war, '
#                           'scientists test a device to solve an energy crisis '
#                           'and end up face-to-face with a dark alternate '
#                           'reality.',
#               'popularity': 18.214868,
#               'poster_path': '/gfxPTyeG9HescyS3EAcMM0VxNg6.jpg',
#               'release_date': '2018-02-04',
#               'title': 'The Cloverfield Paradox',
#               'video': False,
#               'vote_average': 5.7,
#               'vote_count': 836},
#              {'adult': False,
#               'backdrop_path': '/9zDfqJlon06LYwyYyw5p8FtRffN.jpg',
#               'genre_ids': [53],
#               'id': 437375,
#               'original_language': 'en',
#               'original_title': 'Looking Glass',
#               'overview': 'A psycho- sexual thriller following a couple that '
#                           'buys an old motel in the desert looking for a new '
#                           'beginning, but what seemed at first as an escape is '
#                           'soon a thrilling ride through a mysterious world '
#                           'when Ray discovers a two way mirror and witnesses a '
#                           'horrifying murder. In a twisted game of cat and '
#                           'mouse, Ray must race to save his wife and himself '
#                           'from a gruesome secret connected to the motel and '
#                           'the strange people who visit there.',
#               'popularity': 16.405303,
#               'poster_path': '/6zSzaUmoUCwII2pGTqX1jaX8F0p.jpg',
#               'release_date': '2018-02-16',
#               'title': 'Looking Glass',
#               'video': False,
#               'vote_average': 4.9,
#               'vote_count': 19}],
#  'total_pages': 92,
#  'total_results': 1821}
# [{'adult': False,
#   'backdrop_path': '/9ywA15OAiwjSTvg3cBs9B7kOCBF.jpg',
#   'genre_ids': [18, 10749],
#   'id': 337167,
#   'original_language': 'en',
#   'original_title': 'Fifty Shades Freed',
#   'overview': 'Believing they have left behind shadowy figures from their '
#               'past, newlyweds Christian and Ana fully embrace an inextricable '
#               'connection and shared life of luxury. But just as she steps '
#               'into her role as Mrs. Grey and he relaxes into an unfamiliar '
#               'stability, new threats could jeopardize their happy ending '
#               'before it even begins.',
#   'popularity': 457.27461,
#   'poster_path': '/3kcEGnYBHDeqmdYf8ZRbKdfmlUy.jpg',
#   'release_date': '2018-02-07',
#   'title': 'Fifty Shades Freed',
#   'video': False,
#   'vote_average': 6.1,
#   'vote_count': 1196},
#  {'adult': False,
#   'backdrop_path': '/b6ZJZHUdMEFECvGiDpJjlfUWela.jpg',
#   'genre_ids': [28, 12, 14, 878],
#   'id': 284054,
#   'original_language': 'en',
#   'original_title': 'Black Panther',
#   'overview': "King T'Challa returns home from America to the reclusive, "
#               'technologically advanced African nation of Wakanda to serve as '
#               "his country's new leader. However, T'Challa soon finds that he "
#               'is challenged for the throne by factions within his own country '
#               'as well as without.  Using powers reserved to Wakandan kings, '
#               "T'Challa assumes the Black Panther mantel to join with "
#               'girlfriend Nakia, the queen-mother, his princess-kid sister,  '
#               'members of the Dora Milaje (the Wakandan "special forces"), and '
#               'an American secret agent, to prevent Wakanda from being dragged '
#               'into a world war.',
#   'popularity': 204.155126,
#   'poster_path': '/uxzzxijgPIY7slzFvMotPv8wjKA.jpg',
#   'release_date': '2018-02-13',
#   'title': 'Black Panther',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 3819},
#  {'adult': False,
#   'backdrop_path': '/5zfVNTrkhMu673zma6qhFzG01ig.jpg',
#   'genre_ids': [9648, 878, 18],
#   'id': 300668,
#   'original_language': 'en',
#   'original_title': 'Annihilation',
#   'overview': 'A biologist signs up for a dangerous, secret expedition into a '
#               "mysterious zone where the laws of nature don't apply.",
#   'popularity': 91.363378,
#   'poster_path': '/d3qcpfNwbAMCNqWDHzPQsUYiUgS.jpg',
#   'release_date': '2018-02-22',
#   'title': 'Annihilation',
#   'video': False,
#   'vote_average': 6.4,
#   'vote_count': 1248},
#  {'adult': False,
#   'backdrop_path': '/4QrbczSQGZQA7BG9xMhccQI7LHm.jpg',
#   'genre_ids': [18, 10749],
#   'id': 499772,
#   'original_language': 'tl',
#   'original_title': 'Meet Me In St. Gallen',
#   'overview': 'The story of Jesse and Celeste who meets at an unexpected time '
#               'in their lives. They then realize their names are the same as '
#               'the characters in the popular break-up romantic comedy, Celeste '
#               'and Jesse Forever.',
#   'popularity': 76.285636,
#   'poster_path': '/uGntNjUx6YAzbVy7RDgxWnWsdet.jpg',
#   'release_date': '2018-02-07',
#   'title': 'Meet Me In St. Gallen',
#   'video': False,
#   'vote_average': 5.4,
#   'vote_count': 15},
#  {'adult': False,
#   'backdrop_path': '/clmYuR1t4TtKcakIOvYIPrjyxDc.jpg',
#   'genre_ids': [28, 80, 18],
#   'id': 399035,
#   'original_language': 'en',
#   'original_title': 'The Commuter',
#   'overview': 'A businessman on his daily commute home gets unwittingly caught '
#               'up in a criminal conspiracy that threatens not only his life '
#               'but the lives of those around him.',
#   'popularity': 65.501665,
#   'poster_path': '/rDeGK6FIUfVcXmuBdEORPAGPMNg.jpg',
#   'release_date': '2018-01-11',
#   'title': 'The Commuter',
#   'video': False,
#   'vote_average': 5.8,
#   'vote_count': 677},
#  {'adult': False,
#   'backdrop_path': '/PwI3EfasE9fVuXsmMu9ffJh0Re.jpg',
#   'genre_ids': [9648, 27, 53],
#   'id': 406563,
#   'original_language': 'en',
#   'original_title': 'Insidious: The Last Key',
#   'overview': 'Parapsychologist Elise Rainier and her team travel to Five '
#               "Keys, N.M., to investigate a man's claim of a haunting. Terror "
#               'soon strikes when Rainier realizes that the house he lives in '
#               "was her family's old home.",
#   'popularity': 40.687605,
#   'poster_path': '/nb9fc9INMg8kQ8L7sE7XTNsZnUX.jpg',
#   'release_date': '2018-01-03',
#   'title': 'Insidious: The Last Key',
#   'video': False,
#   'vote_average': 6.1,
#   'vote_count': 505},
#  {'adult': False,
#   'backdrop_path': '/bvbyidkMaBls1LTaIWYY6UmYTaL.jpg',
#   'genre_ids': [28, 9648, 878, 53, 12, 14],
#   'id': 336843,
#   'original_language': 'en',
#   'original_title': 'Maze Runner: The Death Cure',
#   'overview': 'Thomas leads his group of escaped Gladers on their final and '
#               'most dangerous mission yet. To save their friends, they must '
#               'break into the legendary Last City, a WCKD-controlled labyrinth '
#               'that may turn out to be the deadliest maze of all. Anyone who '
#               'makes it out alive will get answers to the questions the '
#               'Gladers have been asking since they first arrived in the maze.',
#   'popularity': 36.994424,
#   'poster_path': '/7GgZ6DGezkh3szFdvskH5XD4V0t.jpg',
#   'release_date': '2018-01-17',
#   'title': 'Maze Runner: The Death Cure',
#   'video': False,
#   'vote_average': 7.2,
#   'vote_count': 1108},
#  {'adult': False,
#   'backdrop_path': '/txKjPn6yuqvmdc7YGTnh62EM5Cd.jpg',
#   'genre_ids': [53, 28, 80],
#   'id': 442064,
#   'original_language': 'en',
#   'original_title': 'Proud Mary',
#   'overview': 'A hit woman kills a drug boss only to learn that she has left a '
#               'boy orphaned. A year later, she saves the boy from a dangerous '
#               'life on the street but finds herself unable to give the boy or '
#               'herself a fresh start.',
#   'popularity': 36.143522,
#   'poster_path': '/5luceoVMU2FzWuyty7mZFcSY5ZW.jpg',
#   'release_date': '2018-01-12',
#   'title': 'Proud Mary',
#   'video': False,
#   'vote_average': 5.3,
#   'vote_count': 115},
#  {'adult': False,
#   'backdrop_path': '/iG3wzWkLcnxnwzZHYT6iyd1UqJP.jpg',
#   'genre_ids': [28],
#   'id': 401478,
#   'original_language': 'en',
#   'original_title': 'Death Race 4: Beyond Anarchy',
#   'overview': 'Danny Trejo returns as the ruthless bookie, Goldberg, in the '
#               'wildest, bloodiest, Death Race ever. After a failed attack on '
#               'inmate and legendary driver, Frankenstein, Black Ops specialist '
#               'Connor Gibson (McGowan) infiltrates a super-maximum federal '
#               'prison with one goal - enter the immoral and illegal Death Race '
#               'and take Frankenstein down. Connor enlists the help of '
#               'Baltimore Bob (Glover) and Lists (Koehler), and unexpectedly '
#               'falls in love with bartending beauty, Jane (Marzano). Connor '
#               'will have to fight for more than his life in this brutal world '
#               'of no guards, no rules, no track, and no fear.',
#   'popularity': 34.590488,
#   'poster_path': '/h4CrVSJO8G2xRFgkxjPX8LCLzCk.jpg',
#   'release_date': '2018-01-30',
#   'title': 'Death Race 4: Beyond Anarchy',
#   'video': False,
#   'vote_average': 5.1,
#   'vote_count': 13},
#  {'adult': False,
#   'backdrop_path': '/xCF6Vkq1L5tTGENb07vzlQyXwKv.jpg',
#   'genre_ids': [28, 12, 14],
#   'id': 437543,
#   'original_language': 'zh',
#   'original_title': '西游记·女儿国',
#   'overview': 'The third installment of the blockbuster fantasy series sees '
#               'the return of the Monkey King (Aaron Kwok) in his most '
#               'action-packed adventure yet! While continuing their epic '
#               'journey to the West, the Monkey King and his companions are '
#               'taken captive by the Queen of an all-female land, who believes '
#               'them to be part of an ancient prophecy heralding the fall of '
#               'her kingdom. With a lot of sorcery and a little bit of charm, '
#               'the travelers devise a plan to escape. But when their trickery '
#               'angers the mighty River God, they realize they might just bring '
#               'about the foretold destruction - unless they can find a way to '
#               'quell her wrath.',
#   'popularity': 34.140986,
#   'poster_path': '/zMYnxPIkUVaRIuTpS77B8hLGkBB.jpg',
#   'release_date': '2018-02-16',
#   'title': 'The Monkey King 3: Kingdom of Women',
#   'video': False,
#   'vote_average': 5.3,
#   'vote_count': 8},
#  {'adult': False,
#   'backdrop_path': '/sGzuQYSTwJvLBc2PnuSVLHhuFeh.jpg',
#   'genre_ids': [9648, 53],
#   'id': 401981,
#   'original_language': 'en',
#   'original_title': 'Red Sparrow',
#   'overview': 'Prima ballerina Dominika Egorova faces a bleak and uncertain '
#               'future after she suffers an injury that ends her career. She '
#               'soon turns to Sparrow School, a secret intelligence service '
#               'that trains exceptional young people to use their minds and '
#               'bodies as weapons. Egorova emerges as the most dangerous '
#               'Sparrow after completing the sadistic training process. As she '
#               'comes to terms with her new abilities, Dominika meets a CIA '
#               'agent who tries to convince her that he is the only person she '
#               'can trust.',
#   'popularity': 33.281817,
#   'poster_path': '/fyufzd2S1lLxMxkTHTnmr6VJfe5.jpg',
#   'release_date': '2018-03-01',
#   'title': 'Red Sparrow',
#   'video': False,
#   'vote_average': 6.3,
#   'vote_count': 547},
#  {'adult': False,
#   'backdrop_path': '/lffgWEBiLf9DbDdb86WsGsEcWTg.jpg',
#   'genre_ids': [53, 18, 14],
#   'id': 419831,
#   'original_language': 'en',
#   'original_title': 'I Kill Giants',
#   'overview': 'Barbara Thorson struggles through life by escaping into a '
#               'fantasy life of magic and monsters.',
#   'popularity': 23.829161,
#   'poster_path': '/cvit6HDbXHE6W5kGPd47jd0wthQ.jpg',
#   'release_date': '2018-01-21',
#   'title': 'I Kill Giants',
#   'video': False,
#   'vote_average': 6,
#   'vote_count': 63},
#  {'adult': False,
#   'backdrop_path': '/g1ovo0YhL9FcZmgoW4Fx6F4x1e6.jpg',
#   'genre_ids': [28, 80, 18, 53],
#   'id': 395990,
#   'original_language': 'en',
#   'original_title': 'Death Wish',
#   'overview': 'A mild-mannered father is transformed into a killing machine '
#               'after his family is torn apart by a violent act.',
#   'popularity': 23.329822,
#   'poster_path': '/wamM5AyPAeNPNPfjWRI9WD8dweQ.jpg',
#   'release_date': '2018-03-02',
#   'title': 'Death Wish',
#   'video': False,
#   'vote_average': 4.6,
#   'vote_count': 167},
#  {'adult': False,
#   'backdrop_path': '/p8YMxheGzrtTJgz74EucMJyWqIy.jpg',
#   'genre_ids': [16, 12, 10751],
#   'id': 381719,
#   'original_language': 'en',
#   'original_title': 'Peter Rabbit',
#   'overview': "Feature adaptation of Beatrix Potter's classic tale of a "
#               "rebellious rabbit trying to sneak into a farmer's vegetable "
#               'garden.',
#   'popularity': 21.939166,
#   'poster_path': '/2yjSvEDuM3rLDng40erLsWkQRfn.jpg',
#   'release_date': '2018-02-07',
#   'title': 'Peter Rabbit',
#   'video': False,
#   'vote_average': 6.3,
#   'vote_count': 77},
#  {'adult': False,
#   'backdrop_path': '/jknYekTVH1n7doNVj5wiCMKhx7u.jpg',
#   'genre_ids': [9648, 35, 80, 53],
#   'id': 445571,
#   'original_language': 'en',
#   'original_title': 'Game Night',
#   'overview': "Max and Annie's weekly game night gets kicked up a notch when "
#               "Max's brother Brooks arranges a murder mystery party -- "
#               'complete with fake thugs and federal agents. So when Brooks '
#               "gets kidnapped, it's all supposed to be part of the game. As "
#               'the competitors set out to solve the case, they start to learn '
#               'that neither the game nor Brooks are what they seem to be. The '
#               'friends soon find themselves in over their heads as each twist '
#               'leads to another unexpected turn over the course of one chaotic '
#               'night.',
#   'popularity': 20.374195,
#   'poster_path': '/1wS89vns6cseCn4UHSqj97xKEKW.jpg',
#   'release_date': '2018-02-22',
#   'title': 'Game Night',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 194},
#  {'adult': False,
#   'backdrop_path': '/teunpFRDU3dBiWhGneegrjQ7uSq.jpg',
#   'genre_ids': [9648, 878, 53],
#   'id': 401371,
#   'original_language': 'en',
#   'original_title': 'Mute',
#   'overview': 'A mute man with a violent past is forced to take on the teeming '
#               'underworld of a near-future Berlin as he searches for his '
#               'missing girlfriend.',
#   'popularity': 20.328504,
#   'poster_path': '/ihGg1xndLl3MW34Km332pNkyLH7.jpg',
#   'release_date': '2018-02-23',
#   'title': 'Mute',
#   'video': False,
#   'vote_average': 5.6,
#   'vote_count': 236},
#  {'adult': False,
#   'backdrop_path': '/x5EUEv1N9g4BCX9GQXKvv3nqMVo.jpg',
#   'genre_ids': [10752, 18, 36],
#   'id': 429351,
#   'original_language': 'en',
#   'original_title': '12 Strong',
#   'overview': 'A team of CIA agents and special forces head into Afghanistan '
#               'in the aftermath of the September 11th attacks in an attempt to '
#               'dismantle the Taliban.',
#   'popularity': 19.691142,
#   'poster_path': '/j18021qCeRi3yUBtqd2UFj1c0RQ.jpg',
#   'release_date': '2018-01-18',
#   'title': '12 Strong',
#   'video': False,
#   'vote_average': 4.9,
#   'vote_count': 245},
#  {'adult': False,
#   'backdrop_path': '/uIWnlqVAQWkVXyW1mjsrlvoCItt.jpg',
#   'genre_ids': [18, 28],
#   'id': 459910,
#   'original_language': 'en',
#   'original_title': 'Braven',
#   'overview': 'A logger defends his family from a group of dangerous drug '
#               'runners.',
#   'popularity': 18.75806,
#   'poster_path': '/253Bw5I3Zj3e2thCThjO7byEUCL.jpg',
#   'release_date': '2018-02-01',
#   'title': 'Braven',
#   'video': False,
#   'vote_average': 6.1,
#   'vote_count': 84},
#  {'adult': False,
#   'backdrop_path': '/lX4jScWnurasu6Kxuqo9819mjM2.jpg',
#   'genre_ids': [9648, 53, 27, 878],
#   'id': 384521,
#   'original_language': 'en',
#   'original_title': 'The Cloverfield Paradox',
#   'overview': 'Orbiting above a planet on the brink of war, scientists test a '
#               'device to solve an energy crisis and end up face-to-face with a '
#               'dark alternate reality.',
#   'popularity': 18.214868,
#   'poster_path': '/gfxPTyeG9HescyS3EAcMM0VxNg6.jpg',
#   'release_date': '2018-02-04',
#   'title': 'The Cloverfield Paradox',
#   'video': False,
#   'vote_average': 5.7,
#   'vote_count': 836},
#  {'adult': False,
#   'backdrop_path': '/9zDfqJlon06LYwyYyw5p8FtRffN.jpg',
#   'genre_ids': [53],
#   'id': 437375,
#   'original_language': 'en',
#   'original_title': 'Looking Glass',
#   'overview': 'A psycho- sexual thriller following a couple that buys an old '
#               'motel in the desert looking for a new beginning, but what '
#               'seemed at first as an escape is soon a thrilling ride through a '
#               'mysterious world when Ray discovers a two way mirror and '
#               'witnesses a horrifying murder. In a twisted game of cat and '
#               'mouse, Ray must race to save his wife and himself from a '
#               'gruesome secret connected to the motel and the strange people '
#               'who visit there.',
#   'popularity': 16.405303,
#   'poster_path': '/6zSzaUmoUCwII2pGTqX1jaX8F0p.jpg',
#   'release_date': '2018-02-16',
#   'title': 'Looking Glass',
#   'video': False,
#   'vote_average': 4.9,
#   'vote_count': 19}]

# %%
# Get movie id list from the original data pulled based on number of years
# This information is used to in the second API call --> To pull data based on years and do the analysis, we need two API calls

movie_id_list = []

for movie_id in movies_data_list:
    movie_id_list.append(movie_id["id"])

print(movie_id_list)
# Out:
# [337167, 284054, 300668, 499772, 399035, 406563, 336843, 442064, 401478, 437543, 401981, 419831, 395990, 381719, 445571, 401371, 429351, 459910, 384521, 437375]

# %%
# Using movie id list call the TMDb API for more movie information
url2 = "https://api.themoviedb.org/3/movie/"
movie_details = []

for mve_id in movie_id_list:
    
    response2 = requests.get(f"{url2}{mve_id}?api_key={api_key}")
    movie_details.append(response2.json())
    
pprint(movie_details)
# Out:
# [{'adult': False,
#   'backdrop_path': '/9ywA15OAiwjSTvg3cBs9B7kOCBF.jpg',
#   'belongs_to_collection': {'backdrop_path': '/23fRJTMFRG2lMvvpHcIZ0ZU77I1.jpg',
#                             'id': 344830,
#                             'name': 'Fifty Shades Collection',
#                             'poster_path': '/oJrMaAhQlV5K9QFhulFehTn7JVn.jpg'},
#   'budget': 55000000,
#   'genres': [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}],
#   'homepage': 'http://www.fiftyshadesmovie.com',
#   'id': 337167,
#   'imdb_id': 'tt4477536',
#   'original_language': 'en',
#   'original_title': 'Fifty Shades Freed',
#   'overview': 'Believing they have left behind shadowy figures from their '
#               'past, newlyweds Christian and Ana fully embrace an inextricable '
#               'connection and shared life of luxury. But just as she steps '
#               'into her role as Mrs. Grey and he relaxes into an unfamiliar '
#               'stability, new threats could jeopardize their happy ending '
#               'before it even begins.',
#   'popularity': 456.27461,
#   'poster_path': '/3kcEGnYBHDeqmdYf8ZRbKdfmlUy.jpg',
#   'production_companies': [{'id': 33,
#                             'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png',
#                             'name': 'Universal Pictures',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2018-02-07',
#   'revenue': 136906000,
#   'runtime': 106,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': "Don't miss the climax",
#   'title': 'Fifty Shades Freed',
#   'video': False,
#   'vote_average': 6.1,
#   'vote_count': 1209},
#  {'adult': False,
#   'backdrop_path': '/b6ZJZHUdMEFECvGiDpJjlfUWela.jpg',
#   'belongs_to_collection': None,
#   'budget': 200000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#              {'id': 12, 'name': 'Adventure'},
#              {'id': 14, 'name': 'Fantasy'},
#              {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://marvel.com/movies/movie/224/black_panther',
#   'id': 284054,
#   'imdb_id': 'tt1825683',
#   'original_language': 'en',
#   'original_title': 'Black Panther',
#   'overview': "King T'Challa returns home from America to the reclusive, "
#               'technologically advanced African nation of Wakanda to serve as '
#               "his country's new leader. However, T'Challa soon finds that he "
#               'is challenged for the throne by factions within his own country '
#               'as well as without.  Using powers reserved to Wakandan kings, '
#               "T'Challa assumes the Black Panther mantel to join with "
#               'girlfriend Nakia, the queen-mother, his princess-kid sister,  '
#               'members of the Dora Milaje (the Wakandan "special forces"), and '
#               'an American secret agent, to prevent Wakanda from being dragged '
#               'into a world war.',
#   'popularity': 203.155126,
#   'poster_path': '/uxzzxijgPIY7slzFvMotPv8wjKA.jpg',
#   'production_companies': [{'id': 420,
#                             'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#                             'name': 'Marvel Studios',
#                             'origin_country': 'US'},
#                            {'id': 2,
#                             'logo_path': '/4MbjW4f9bu6LvlDmyIvfyuT3boj.png',
#                             'name': 'Walt Disney Pictures',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2018-02-13',
#   'revenue': 1280926086,
#   'runtime': 134,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'},
#                        {'iso_639_1': 'ko', 'name': '한국어/조선말'},
#                        {'iso_639_1': 'sw', 'name': 'Kiswahili'},
#                        {'iso_639_1': 'xh', 'name': ''}],
#   'status': 'Released',
#   'tagline': 'Long live the king',
#   'title': 'Black Panther',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 3827},
#  {'adult': False,
#   'backdrop_path': '/5zfVNTrkhMu673zma6qhFzG01ig.jpg',
#   'belongs_to_collection': None,
#   'budget': 40000000,
#   'genres': [{'id': 9648, 'name': 'Mystery'},
#              {'id': 878, 'name': 'Science Fiction'},
#              {'id': 18, 'name': 'Drama'}],
#   'homepage': 'http://annihilationmovie.com',
#   'id': 300668,
#   'imdb_id': 'tt2798920',
#   'original_language': 'en',
#   'original_title': 'Annihilation',
#   'overview': 'A biologist signs up for a dangerous, secret expedition into a '
#               "mysterious zone where the laws of nature don't apply.",
#   'popularity': 90.363378,
#   'poster_path': '/d3qcpfNwbAMCNqWDHzPQsUYiUgS.jpg',
#   'production_companies': [{'id': 284,
#                             'logo_path': None,
#                             'name': 'DNA Films',
#                             'origin_country': 'GB'},
#                            {'id': 4,
#                             'logo_path': '/fycMZt242LVjagMByZOLUGbCvv3.png',
#                             'name': 'Paramount',
#                             'origin_country': 'US'},
#                            {'id': 258,
#                             'logo_path': None,
#                             'name': 'Scott Rudin Productions',
#                             'origin_country': 'US'},
#                            {'id': 82819,
#                             'logo_path': '/zlFa3VNua4hJyGEI4X2sqDrtEH9.png',
#                             'name': 'Skydance Media',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#                            {'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2018-02-22',
#   'revenue': 13258603,
#   'runtime': 115,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': "Fear What's Inside.",
#   'title': 'Annihilation',
#   'video': False,
#   'vote_average': 6.3,
#   'vote_count': 1316},
#  {'adult': False,
#   'backdrop_path': '/4QrbczSQGZQA7BG9xMhccQI7LHm.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}],
#   'homepage': None,
#   'id': 499772,
#   'imdb_id': 'tt7967834',
#   'original_language': 'tl',
#   'original_title': 'Meet Me In St. Gallen',
#   'overview': 'The story of Jesse and Celeste who meets at an unexpected time '
#               'in their lives. They then realize their names are the same as '
#               'the characters in the popular break-up romantic comedy, Celeste '
#               'and Jesse Forever.',
#   'popularity': 75.285636,
#   'poster_path': '/uGntNjUx6YAzbVy7RDgxWnWsdet.jpg',
#   'production_companies': [{'id': 8356,
#                             'logo_path': None,
#                             'name': 'Viva Films',
#                             'origin_country': 'PH'},
#                            {'id': 9158,
#                             'logo_path': None,
#                             'name': 'Spring Films',
#                             'origin_country': 'PH'}],
#   'production_countries': [{'iso_3166_1': 'PH', 'name': 'Philippines'}],
#   'release_date': '2018-02-07',
#   'revenue': 0,
#   'runtime': None,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'},
#                        {'iso_639_1': 'tl', 'name': ''}],
#   'status': 'Post Production',
#   'tagline': '',
#   'title': 'Meet Me In St. Gallen',
#   'video': False,
#   'vote_average': 4.9,
#   'vote_count': 20},
#  {'adult': False,
#   'backdrop_path': '/clmYuR1t4TtKcakIOvYIPrjyxDc.jpg',
#   'belongs_to_collection': None,
#   'budget': 30000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#              {'id': 80, 'name': 'Crime'},
#              {'id': 18, 'name': 'Drama'}],
#   'homepage': 'https://thecommuter.movie/',
#   'id': 399035,
#   'imdb_id': 'tt1590193',
#   'original_language': 'en',
#   'original_title': 'The Commuter',
#   'overview': 'A businessman on his daily commute home gets unwittingly caught '
#               'up in a criminal conspiracy that threatens not only his life '
#               'but the lives of those around him.',
#   'popularity': 64.501665,
#   'poster_path': '/rDeGK6FIUfVcXmuBdEORPAGPMNg.jpg',
#   'production_companies': [{'id': 694,
#                             'logo_path': '/8T8OOQe3Xei2mW0DQepwQG1IMT0.png',
#                             'name': 'StudioCanal',
#                             'origin_country': 'FR'},
#                            {'id': 23513,
#                             'logo_path': None,
#                             'name': 'Ombra Films',
#                             'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'FR', 'name': 'France'},
#                            {'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#                            {'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2018-01-11',
#   'revenue': 105652788,
#   'runtime': 104,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Lives are on the line',
#   'title': 'The Commuter',
#   'video': False,
#   'vote_average': 5.8,
#   'vote_count': 677},
#  {'adult': False,
#   'backdrop_path': '/PwI3EfasE9fVuXsmMu9ffJh0Re.jpg',
#   'belongs_to_collection': {'backdrop_path': '/5FrPZHgbbmTIq0oxpwSGqu5HyXC.jpg',
#                             'id': 228446,
#                             'name': 'Insidious Collection',
#                             'poster_path': '/fct5wsWu6niDIGRIC4aWEsN5Npa.jpg'},
#   'budget': 10000000,
#   'genres': [{'id': 9648, 'name': 'Mystery'},
#              {'id': 27, 'name': 'Horror'},
#              {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'http://www.insidiousmovie.com',
#   'id': 406563,
#   'imdb_id': 'tt5726086',
#   'original_language': 'en',
#   'original_title': 'Insidious: The Last Key',
#   'overview': 'Parapsychologist Elise Rainier and her team travel to Five '
#               "Keys, N.M., to investigate a man's claim of a haunting. Terror "
#               'soon strikes when Rainier realizes that the house he lives in '
#               "was her family's old home.",
#   'popularity': 39.687605,
#   'poster_path': '/nb9fc9INMg8kQ8L7sE7XTNsZnUX.jpg',
#   'production_companies': [{'id': 11341,
#                             'logo_path': None,
#                             'name': 'Stage 6 Films',
#                             'origin_country': ''},
#                            {'id': 3172,
#                             'logo_path': None,
#                             'name': 'Blumhouse Productions',
#                             'origin_country': ''},
#                            {'id': 5,
#                             'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png',
#                             'name': 'Columbia Pictures',
#                             'origin_country': 'US'},
#                            {'id': 8147,
#                             'logo_path': '/q6HOAdSNgCbeOqwoMVRc6REgbXF.png',
#                             'name': 'Entertainment One',
#                             'origin_country': 'CA'},
#                            {'id': 34034,
#                             'logo_path': None,
#                             'name': 'LStar Capital',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2018-01-03',
#   'revenue': 165242521,
#   'runtime': 118,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Fear comes home.',
#   'title': 'Insidious: The Last Key',
#   'video': False,
#   'vote_average': 6.1,
#   'vote_count': 507},
#  {'adult': False,
#   'backdrop_path': '/bvbyidkMaBls1LTaIWYY6UmYTaL.jpg',
#   'belongs_to_collection': {'backdrop_path': '/eQ8iwAvGfuNnPjBCKTIVp5PsFw.jpg',
#                             'id': 295130,
#                             'name': 'The Maze Runner Collection',
#                             'poster_path': '/9TzEraXQoy4Y3Ec5AcHaN9Rtb60.jpg'},
#   'budget': 62000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#              {'id': 9648, 'name': 'Mystery'},
#              {'id': 878, 'name': 'Science Fiction'},
#              {'id': 53, 'name': 'Thriller'},
#              {'id': 12, 'name': 'Adventure'},
#              {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'http://mazerunnermovies.com',
#   'id': 336843,
#   'imdb_id': 'tt4500922',
#   'original_language': 'en',
#   'original_title': 'Maze Runner: The Death Cure',
#   'overview': 'Thomas leads his group of escaped Gladers on their final and '
#               'most dangerous mission yet. To save their friends, they must '
#               'break into the legendary Last City, a WCKD-controlled labyrinth '
#               'that may turn out to be the deadliest maze of all. Anyone who '
#               'makes it out alive will get answers to the questions the '
#               'Gladers have been asking since they first arrived in the maze.',
#   'popularity': 35.994424,
#   'poster_path': '/7GgZ6DGezkh3szFdvskH5XD4V0t.jpg',
#   'production_companies': [{'id': 3672,
#                             'logo_path': '/5VWXJgYYrJZUE0hixvBdVfGSfmo.png',
#                             'name': 'Gotham Group',
#                             'origin_country': ''},
#                            {'id': 12292,
#                             'logo_path': '/4GQTeqos2luopEtp3OgMQYusQ5c.png',
#                             'name': 'Temple Hill Entertainment',
#                             'origin_country': 'US'},
#                            {'id': 25,
#                             'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png',
#                             'name': '20th Century Fox',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2018-01-17',
#   'revenue': 259854591,
#   'runtime': 142,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'},
#                        {'iso_639_1': 'de', 'name': 'Deutsch'},
#                        {'iso_639_1': 'es', 'name': 'Español'}],
#   'status': 'Released',
#   'tagline': 'The end will be WCKD',
#   'title': 'Maze Runner: The Death Cure',
#   'video': False,
#   'vote_average': 7.2,
#   'vote_count': 1146},
#  {'adult': False,
#   'backdrop_path': '/txKjPn6yuqvmdc7YGTnh62EM5Cd.jpg',
#   'belongs_to_collection': None,
#   'budget': 14000000,
#   'genres': [{'id': 53, 'name': 'Thriller'},
#              {'id': 28, 'name': 'Action'},
#              {'id': 80, 'name': 'Crime'}],
#   'homepage': 'http://www.proudmary-movie.com',
#   'id': 442064,
#   'imdb_id': 'tt6421110',
#   'original_language': 'en',
#   'original_title': 'Proud Mary',
#   'overview': 'A hit woman kills a drug boss only to learn that she has left a '
#               'boy orphaned. A year later, she saves the boy from a dangerous '
#               'life on the street but finds herself unable to give the boy or '
#               'herself a fresh start.',
#   'popularity': 35.143522,
#   'poster_path': '/5luceoVMU2FzWuyty7mZFcSY5ZW.jpg',
#   'production_companies': [{'id': 34,
#                             'logo_path': '/GagSvqWlyPdkFHMfQ3pNq6ix9P.png',
#                             'name': 'Sony Pictures',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2018-01-12',
#   'revenue': 19766319,
#   'runtime': 88,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Proud Mary',
#   'video': False,
#   'vote_average': 5.3,
#   'vote_count': 115},
#  {'adult': False,
#   'backdrop_path': '/iG3wzWkLcnxnwzZHYT6iyd1UqJP.jpg',
#   'belongs_to_collection': {'backdrop_path': '/cGaVuq8ZjX1UPD9wPRlzx6lP9kK.jpg',
#                             'id': 86116,
#                             'name': 'Death Race Collection',
#                             'poster_path': '/uffHLg0ekFlErCp7OkpecXkWPng.jpg'},
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'}],
#   'homepage': None,
#   'id': 401478,
#   'imdb_id': 'tt3807900',
#   'original_language': 'en',
#   'original_title': 'Death Race 4: Beyond Anarchy',
#   'overview': 'Danny Trejo returns as the ruthless bookie, Goldberg, in the '
#               'wildest, bloodiest, Death Race ever. After a failed attack on '
#               'inmate and legendary driver, Frankenstein, Black Ops specialist '
#               'Connor Gibson (McGowan) infiltrates a super-maximum federal '
#               'prison with one goal - enter the immoral and illegal Death Race '
#               'and take Frankenstein down. Connor enlists the help of '
#               'Baltimore Bob (Glover) and Lists (Koehler), and unexpectedly '
#               'falls in love with bartending beauty, Jane (Marzano). Connor '
#               'will have to fight for more than his life in this brutal world '
#               'of no guards, no rules, no track, and no fear.',
#   'popularity': 33.590488,
#   'poster_path': '/h4CrVSJO8G2xRFgkxjPX8LCLzCk.jpg',
#   'production_companies': [{'id': 2365,
#                             'logo_path': None,
#                             'name': 'Capital Arts Entertainment',
#                             'origin_country': ''},
#                            {'id': 7188,
#                             'logo_path': None,
#                             'name': 'UFO International Productions',
#                             'origin_country': ''},
#                            {'id': 17009,
#                             'logo_path': None,
#                             'name': 'Universal 1440 Entertainment',
#                             'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2018-01-30',
#   'revenue': 0,
#   'runtime': 111,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'},
#                        {'iso_639_1': 'fr', 'name': 'Français'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Death Race 4: Beyond Anarchy',
#   'video': False,
#   'vote_average': 5.1,
#   'vote_count': 14},
#  {'adult': False,
#   'backdrop_path': '/xCF6Vkq1L5tTGENb07vzlQyXwKv.jpg',
#   'belongs_to_collection': {'backdrop_path': '/ep95Ixc8H0Wrw7PTl94QG4diK6F.jpg',
#                             'id': 392206,
#                             'name': 'The Monkey King Collection',
#                             'poster_path': '/m5J6XxjDY0jcTKjklem2NAsAnx4.jpg'},
#   'budget': 73000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#              {'id': 12, 'name': 'Adventure'},
#              {'id': 14, 'name': 'Fantasy'}],
#   'homepage': None,
#   'id': 437543,
#   'imdb_id': 'tt6466464',
#   'original_language': 'zh',
#   'original_title': '西游记·女儿国',
#   'overview': 'The third installment of the blockbuster fantasy series sees '
#               'the return of the Monkey King (Aaron Kwok) in his most '
#               'action-packed adventure yet! While continuing their epic '
#               'journey to the West, the Monkey King and his companions are '
#               'taken captive by the Queen of an all-female land, who believes '
#               'them to be part of an ancient prophecy heralding the fall of '
#               'her kingdom. With a lot of sorcery and a little bit of charm, '
#               'the travelers devise a plan to escape. But when their trickery '
#               'angers the mighty River God, they realize they might just bring '
#               'about the foretold destruction - unless they can find a way to '
#               'quell her wrath.',
#   'popularity': 33.140986,
#   'poster_path': '/zMYnxPIkUVaRIuTpS77B8hLGkBB.jpg',
#   'production_companies': [],
#   'production_countries': [{'iso_3166_1': 'CN', 'name': 'China'}],
#   'release_date': '2018-02-16',
#   'revenue': 0,
#   'runtime': 114,
#   'spoken_languages': [{'iso_639_1': 'zh', 'name': '普通话'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'The Monkey King 3: Kingdom of Women',
#   'video': False,
#   'vote_average': 4.4,
#   'vote_count': 10},
#  {'adult': False,
#   'backdrop_path': '/sGzuQYSTwJvLBc2PnuSVLHhuFeh.jpg',
#   'belongs_to_collection': None,
#   'budget': 69000000,
#   'genres': [{'id': 9648, 'name': 'Mystery'}, {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.foxmovies.com/movies/red-sparrow',
#   'id': 401981,
#   'imdb_id': 'tt2873282',
#   'original_language': 'en',
#   'original_title': 'Red Sparrow',
#   'overview': 'Prima ballerina Dominika Egorova faces a bleak and uncertain '
#               'future after she suffers an injury that ends her career. She '
#               'soon turns to Sparrow School, a secret intelligence service '
#               'that trains exceptional young people to use their minds and '
#               'bodies as weapons. Egorova emerges as the most dangerous '
#               'Sparrow after completing the sadistic training process. As she '
#               'comes to terms with her new abilities, Dominika meets a CIA '
#               'agent who tries to convince her that he is the only person she '
#               'can trust.',
#   'popularity': 32.281817,
#   'poster_path': '/fyufzd2S1lLxMxkTHTnmr6VJfe5.jpg',
#   'production_companies': [{'id': 99426,
#                             'logo_path': None,
#                             'name': 'Soundtrack New York',
#                             'origin_country': ''},
#                            {'id': 7076,
#                             'logo_path': '/8BFxn9NUWSgp0ndih569Gm62xiC.png',
#                             'name': 'Chernin Entertainment',
#                             'origin_country': 'US'},
#                            {'id': 8083,
#                             'logo_path': None,
#                             'name': 'Film Rites',
#                             'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2018-03-01',
#   'revenue': 83607124,
#   'runtime': 139,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Seduce. Deceive. Repeat.',
#   'title': 'Red Sparrow',
#   'video': False,
#   'vote_average': 6.3,
#   'vote_count': 581},
#  {'adult': False,
#   'backdrop_path': '/lffgWEBiLf9DbDdb86WsGsEcWTg.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 53, 'name': 'Thriller'},
#              {'id': 18, 'name': 'Drama'},
#              {'id': 14, 'name': 'Fantasy'}],
#   'homepage': None,
#   'id': 419831,
#   'imdb_id': 'tt4547194',
#   'original_language': 'en',
#   'original_title': 'I Kill Giants',
#   'overview': 'Barbara Thorson struggles through life by escaping into a '
#               'fantasy life of magic and monsters.',
#   'popularity': 22.829161,
#   'poster_path': '/cvit6HDbXHE6W5kGPd47jd0wthQ.jpg',
#   'production_companies': [{'id': 12142,
#                             'logo_path': '/rPnEeMwxjI6rYMGqkWqIWwIJXxi.png',
#                             'name': 'XYZ Films',
#                             'origin_country': 'US'},
#                            {'id': 436,
#                             'logo_path': None,
#                             'name': '1492 Pictures',
#                             'origin_country': 'US'},
#                            {'id': 100877,
#                             'logo_path': None,
#                             'name': 'Having Me Films',
#                             'origin_country': 'CN'},
#                            {'id': 36434,
#                             'logo_path': '/57HyIzqTJMO2rYGjhQbrwITFWV0.png',
#                             'name': 'Ocean Blue Entertainment',
#                             'origin_country': 'US'},
#                            {'id': 100861,
#                             'logo_path': '/tceh2aAORA5JxIZSLQ1GkzTBZDL.png',
#                             'name': 'uMedia',
#                             'origin_country': 'BE'},
#                            {'id': 22127,
#                             'logo_path': '/lgkXXc4hyHH6WqVMJVUFrhFIjm5.png',
#                             'name': 'uFund',
#                             'origin_country': 'BE'},
#                            {'id': 78253,
#                             'logo_path': None,
#                             'name': 'Man of Action',
#                             'origin_country': 'US'},
#                            {'id': 102527,
#                             'logo_path': None,
#                             'name': 'Adonis Production',
#                             'origin_country': ''},
#                            {'id': 5122,
#                             'logo_path': None,
#                             'name': 'Parallel Films',
#                             'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'BE', 'name': 'Belgium'},
#                            {'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#   'release_date': '2018-01-21',
#   'revenue': 0,
#   'runtime': 106,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'I Kill Giants',
#   'video': False,
#   'vote_average': 6.0,
#   'vote_count': 65},
#  {'adult': False,
#   'backdrop_path': '/g1ovo0YhL9FcZmgoW4Fx6F4x1e6.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 28, 'name': 'Action'},
#              {'id': 80, 'name': 'Crime'},
#              {'id': 18, 'name': 'Drama'},
#              {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.deathwish.movie/',
#   'id': 395990,
#   'imdb_id': 'tt1137450',
#   'original_language': 'en',
#   'original_title': 'Death Wish',
#   'overview': 'A mild-mannered father is transformed into a killing machine '
#               'after his family is torn apart by a violent act.',
#   'popularity': 22.329822,
#   'poster_path': '/wamM5AyPAeNPNPfjWRI9WD8dweQ.jpg',
#   'production_companies': [{'id': 4,
#                             'logo_path': '/fycMZt242LVjagMByZOLUGbCvv3.png',
#                             'name': 'Paramount',
#                             'origin_country': 'US'},
#                            {'id': 21,
#                             'logo_path': '/zcxym93i5BTqqjhVvAhV5HPwYTR.png',
#                             'name': 'Metro-Goldwyn-Mayer',
#                             'origin_country': 'US'},
#                            {'id': 102500,
#                             'logo_path': None,
#                             'name': 'Cave 76',
#                             'origin_country': ''},
#                            {'id': 102501,
#                             'logo_path': None,
#                             'name': 'Spy Kids 4 SPV',
#                             'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2018-03-02',
#   'revenue': 0,
#   'runtime': 108,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Death Wish',
#   'video': False,
#   'vote_average': 4.6,
#   'vote_count': 167},
#  {'adult': False,
#   'backdrop_path': '/p8YMxheGzrtTJgz74EucMJyWqIy.jpg',
#   'belongs_to_collection': None,
#   'budget': 50000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#              {'id': 12, 'name': 'Adventure'},
#              {'id': 10751, 'name': 'Family'}],
#   'homepage': None,
#   'id': 381719,
#   'imdb_id': 'tt5117670',
#   'original_language': 'en',
#   'original_title': 'Peter Rabbit',
#   'overview': "Feature adaptation of Beatrix Potter's classic tale of a "
#               "rebellious rabbit trying to sneak into a farmer's vegetable "
#               'garden.',
#   'popularity': 20.939166,
#   'poster_path': '/2yjSvEDuM3rLDng40erLsWkQRfn.jpg',
#   'production_companies': [{'id': 2251,
#                             'logo_path': '/8PUjvTVmtJDdDXURTaSoPID0Boj.png',
#                             'name': 'Sony Pictures Animation',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2018-02-07',
#   'revenue': 0,
#   'runtime': 93,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Rascal. Rebel. Rabbit.',
#   'title': 'Peter Rabbit',
#   'video': False,
#   'vote_average': 6.3,
#   'vote_count': 77},
#  {'adult': False,
#   'backdrop_path': '/jknYekTVH1n7doNVj5wiCMKhx7u.jpg',
#   'belongs_to_collection': None,
#   'budget': 37000000,
#   'genres': [{'id': 9648, 'name': 'Mystery'},
#              {'id': 35, 'name': 'Comedy'},
#              {'id': 80, 'name': 'Crime'},
#              {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'http://www.gamenight-movie.com/',
#   'id': 445571,
#   'imdb_id': 'tt2704998',
#   'original_language': 'en',
#   'original_title': 'Game Night',
#   'overview': "Max and Annie's weekly game night gets kicked up a notch when "
#               "Max's brother Brooks arranges a murder mystery party -- "
#               'complete with fake thugs and federal agents. So when Brooks '
#               "gets kidnapped, it's all supposed to be part of the game. As "
#               'the competitors set out to solve the case, they start to learn '
#               'that neither the game nor Brooks are what they seem to be. The '
#               'friends soon find themselves in over their heads as each twist '
#               'leads to another unexpected turn over the course of one chaotic '
#               'night.',
#   'popularity': 19.374195,
#   'poster_path': '/1wS89vns6cseCn4UHSqj97xKEKW.jpg',
#   'production_companies': [{'id': 12,
#                             'logo_path': '/iaYpEp3LQmb8AfAtmTvpqd4149c.png',
#                             'name': 'New Line Cinema',
#                             'origin_country': 'US'},
#                            {'id': 37361,
#                             'logo_path': None,
#                             'name': 'Aggregate Films',
#                             'origin_country': ''},
#                            {'id': 1302,
#                             'logo_path': '/oyzh3Ax1DLJ5gbNRgD6JgMz9Uvd.png',
#                             'name': 'Davis Entertainment',
#                             'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2018-02-22',
#   'revenue': 101887030,
#   'runtime': 100,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'This is not a game.',
#   'title': 'Game Night',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 198},
#  {'adult': False,
#   'backdrop_path': '/teunpFRDU3dBiWhGneegrjQ7uSq.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 9648, 'name': 'Mystery'},
#              {'id': 878, 'name': 'Science Fiction'},
#              {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.netflix.com/title/80119233',
#   'id': 401371,
#   'imdb_id': 'tt1464763',
#   'original_language': 'en',
#   'original_title': 'Mute',
#   'overview': 'A mute man with a violent past is forced to take on the teeming '
#               'underworld of a near-future Berlin as he searches for his '
#               'missing girlfriend.',
#   'popularity': 19.328504,
#   'poster_path': '/ihGg1xndLl3MW34Km332pNkyLH7.jpg',
#   'production_companies': [{'id': 59811,
#                             'logo_path': '/wwemzKWzjKYJFfCeiB57q3r4Bcm.png',
#                             'name': 'Netflix',
#                             'origin_country': 'US'},
#                            {'id': 264,
#                             'logo_path': None,
#                             'name': 'Studio Babelsberg',
#                             'origin_country': ''},
#                            {'id': 3316,
#                             'logo_path': None,
#                             'name': 'Liberty Films UK',
#                             'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'DE', 'name': 'Germany'},
#                            {'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#   'release_date': '2018-02-23',
#   'revenue': 0,
#   'runtime': 126,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'},
#                        {'iso_639_1': 'de', 'name': 'Deutsch'}],
#   'status': 'Released',
#   'tagline': 'He doesn’t need words.',
#   'title': 'Mute',
#   'video': False,
#   'vote_average': 5.6,
#   'vote_count': 241},
#  {'adult': False,
#   'backdrop_path': '/x5EUEv1N9g4BCX9GQXKvv3nqMVo.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 10752, 'name': 'War'},
#              {'id': 18, 'name': 'Drama'},
#              {'id': 36, 'name': 'History'}],
#   'homepage': 'https://12strongmovie.com',
#   'id': 429351,
#   'imdb_id': 'tt1413492',
#   'original_language': 'en',
#   'original_title': '12 Strong',
#   'overview': 'A team of CIA agents and special forces head into Afghanistan '
#               'in the aftermath of the September 11th attacks in an attempt to '
#               'dismantle the Taliban.',
#   'popularity': 18.691142,
#   'poster_path': '/j18021qCeRi3yUBtqd2UFj1c0RQ.jpg',
#   'production_companies': [{'id': 79529,
#                             'logo_path': '/gVN3k8emmKy4iV4KREWcCtxusZK.png',
#                             'name': 'Torridon Films',
#                             'origin_country': 'US'},
#                            {'id': 1088,
#                             'logo_path': None,
#                             'name': 'Alcon Entertainment',
#                             'origin_country': 'US'},
#                            {'id': 33681,
#                             'logo_path': None,
#                             'name': 'Black Label Media',
#                             'origin_country': ''},
#                            {'id': 130,
#                             'logo_path': '/c9dVHPOL3cqCr2593Ahk0nEKTEM.png',
#                             'name': 'Jerry Bruckheimer Films',
#                             'origin_country': 'US'},
#                            {'id': 1632,
#                             'logo_path': '/cisLn1YAUuptXVBa0xjq7ST9cH0.png',
#                             'name': 'Lionsgate',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2018-01-18',
#   'revenue': 47965355,
#   'runtime': 130,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The declassified true story of the horse soldiers',
#   'title': '12 Strong',
#   'video': False,
#   'vote_average': 4.9,
#   'vote_count': 244},
#  {'adult': False,
#   'backdrop_path': '/uIWnlqVAQWkVXyW1mjsrlvoCItt.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}],
#   'homepage': None,
#   'id': 459910,
#   'imdb_id': 'tt5001754',
#   'original_language': 'en',
#   'original_title': 'Braven',
#   'overview': 'A logger defends his family from a group of dangerous drug '
#               'runners.',
#   'popularity': 17.75806,
#   'poster_path': '/253Bw5I3Zj3e2thCThjO7byEUCL.jpg',
#   'production_companies': [{'id': 27049,
#                             'logo_path': None,
#                             'name': 'Pride of Gypsies',
#                             'origin_country': ''},
#                            {'id': 85563,
#                             'logo_path': None,
#                             'name': 'Tinker Productions',
#                             'origin_country': ''},
#                            {'id': 101838,
#                             'logo_path': None,
#                             'name': 'Braven NL',
#                             'origin_country': 'CA'},
#                            {'id': 51526,
#                             'logo_path': None,
#                             'name': 'Hassell Free Production',
#                             'origin_country': ''},
#                            {'id': 290,
#                             'logo_path': None,
#                             'name': 'Ingenious Media',
#                             'origin_country': 'GB'}],
#   'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'}],
#   'release_date': '2018-02-01',
#   'revenue': 0,
#   'runtime': 94,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': '',
#   'title': 'Braven',
#   'video': False,
#   'vote_average': 6.1,
#   'vote_count': 84},
#  {'adult': False,
#   'backdrop_path': '/lX4jScWnurasu6Kxuqo9819mjM2.jpg',
#   'belongs_to_collection': {'backdrop_path': '/38rtwGmYMfhhYH8LZaegfCT1x8K.jpg',
#                             'id': 515434,
#                             'name': 'Cloverfield Collection',
#                             'poster_path': '/wBqObgSSxWLpCt8SvqGIUeTPgCx.jpg'},
#   'budget': 10000000,
#   'genres': [{'id': 9648, 'name': 'Mystery'},
#              {'id': 53, 'name': 'Thriller'},
#              {'id': 27, 'name': 'Horror'},
#              {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.netflix.com/title/80134431',
#   'id': 384521,
#   'imdb_id': 'tt2548396',
#   'original_language': 'en',
#   'original_title': 'The Cloverfield Paradox',
#   'overview': 'Orbiting above a planet on the brink of war, scientists test a '
#               'device to solve an energy crisis and end up face-to-face with a '
#               'dark alternate reality.',
#   'popularity': 17.214868,
#   'poster_path': '/gfxPTyeG9HescyS3EAcMM0VxNg6.jpg',
#   'production_companies': [{'id': 4,
#                             'logo_path': '/fycMZt242LVjagMByZOLUGbCvv3.png',
#                             'name': 'Paramount',
#                             'origin_country': 'US'},
#                            {'id': 11461,
#                             'logo_path': '/p9FoEt5shEKRWRKVIlvFaEmRnun.png',
#                             'name': 'Bad Robot',
#                             'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2018-02-04',
#   'revenue': 0,
#   'runtime': 102,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The future unleashed every thing',
#   'title': 'The Cloverfield Paradox',
#   'video': False,
#   'vote_average': 5.7,
#   'vote_count': 846},
#  {'adult': False,
#   'backdrop_path': '/9zDfqJlon06LYwyYyw5p8FtRffN.jpg',
#   'belongs_to_collection': None,
#   'budget': 0,
#   'genres': [{'id': 53, 'name': 'Thriller'}],
#   'homepage': 'http://www.momentumpictures.net/looking-glass',
#   'id': 437375,
#   'imdb_id': 'tt6083648',
#   'original_language': 'en',
#   'original_title': 'Looking Glass',
#   'overview': 'A psycho- sexual thriller following a couple that buys an old '
#               'motel in the desert looking for a new beginning, but what '
#               'seemed at first as an escape is soon a thrilling ride through a '
#               'mysterious world when Ray discovers a two way mirror and '
#               'witnesses a horrifying murder. In a twisted game of cat and '
#               'mouse, Ray must race to save his wife and himself from a '
#               'gruesome secret connected to the motel and the strange people '
#               'who visit there.',
#   'popularity': 15.405303,
#   'poster_path': '/6zSzaUmoUCwII2pGTqX1jaX8F0p.jpg',
#   'production_companies': [{'id': 95598,
#                             'logo_path': None,
#                             'name': 'Kirk Shaw Productions',
#                             'origin_country': ''},
#                            {'id': 40797,
#                             'logo_path': None,
#                             'name': 'Prettybird',
#                             'origin_country': ''},
#                            {'id': 49969,
#                             'logo_path': None,
#                             'name': 'Silver State Production Services',
#                             'origin_country': ''}],
#   'production_countries': [{'iso_3166_1': 'US',
#                             'name': 'United States of America'}],
#   'release_date': '2018-02-16',
#   'revenue': 0,
#   'runtime': 103,
#   'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Seeing is deceiving',
#   'title': 'Looking Glass',
#   'video': False,
#   'vote_average': 4.9,
#   'vote_count': 19}]

# %%
movie_id1 = []
movie_title = []
budget = []
revenue = []
release_date = []
genre = []
production_comp = []

for detail in movie_details:
    pprint(detail)
    movie_id1.append(detail["id"])
    movie_title.append(detail["original_title"])
    budget.append(detail["budget"])
    revenue.append(detail["revenue"])
    genre.append(detail["genres"][0]["name"])
    production_comp.append(detail["production_companies"][:-1]["name"])

movie_df_frame = pd.DataFrame({"ID":movie_id1,"Title": movie_title, "Budget":budget, "Revenue": revenue, "Genre": genre, "Production Company": production_comp})
#movie_df_frame
# Out:
# {'adult': False,
#  'backdrop_path': '/9ywA15OAiwjSTvg3cBs9B7kOCBF.jpg',
#  'belongs_to_collection': {'backdrop_path': '/23fRJTMFRG2lMvvpHcIZ0ZU77I1.jpg',
#                            'id': 344830,
#                            'name': 'Fifty Shades Collection',
#                            'poster_path': '/oJrMaAhQlV5K9QFhulFehTn7JVn.jpg'},
#  'budget': 55000000,
#  'genres': [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}],
#  'homepage': 'http://www.fiftyshadesmovie.com',
#  'id': 337167,
#  'imdb_id': 'tt4477536',
#  'original_language': 'en',
#  'original_title': 'Fifty Shades Freed',
#  'overview': 'Believing they have left behind shadowy figures from their past, '
#              'newlyweds Christian and Ana fully embrace an inextricable '
#              'connection and shared life of luxury. But just as she steps into '
#              'her role as Mrs. Grey and he relaxes into an unfamiliar '
#              'stability, new threats could jeopardize their happy ending '
#              'before it even begins.',
#  'popularity': 456.27461,
#  'poster_path': '/3kcEGnYBHDeqmdYf8ZRbKdfmlUy.jpg',
#  'production_companies': [{'id': 33,
#                            'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png',
#                            'name': 'Universal Pictures',
#                            'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#                            'name': 'United States of America'}],
#  'release_date': '2018-02-07',
#  'revenue': 136906000,
#  'runtime': 106,
#  'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#  'status': 'Released',
#  'tagline': "Don't miss the climax",
#  'title': 'Fifty Shades Freed',
#  'video': False,
#  'vote_average': 6.1,
#  'vote_count': 1209}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-30d7f306a5b7> in <module>()
#      14     revenue.append(detail["revenue"])
#      15     genre.append(detail["genres"][0]["name"])
# ---> 16     production_comp.append(detail["production_companies"][:-1]["name"])
#      17
#      18 movie_df_frame = pd.DataFrame({"ID":movie_id1,"Title": movie_title, "Budget":budget, "Revenue": revenue, "Genre": genre, "Production Company": production_comp})
#
# TypeError: list indices must be integers or slices, not str
